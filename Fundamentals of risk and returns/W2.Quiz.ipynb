# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import pandas as pd
import edhec_risk_kit as erk
import numpy as np
import matplotlib
from scipy.optimize import minimize
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
hfi = erk.get_hfi_returns()
hfi
# Out:
#          Convertible Arbitrage  CTA Global  Distressed Securities  \
# date
# 1997-01                 0.0119      0.0393                 0.0178
# 1997-02                 0.0123      0.0298                 0.0122
# 1997-03                 0.0078     -0.0021                -0.0012
# 1997-04                 0.0086     -0.0170                 0.0030
# 1997-05                 0.0156     -0.0015                 0.0233
# ...                        ...         ...                    ...
# 2018-07                 0.0021     -0.0058                 0.0093
# 2018-08                 0.0024      0.0166                 0.0002
# 2018-09                 0.0034     -0.0054                 0.0050
# 2018-10                -0.0073     -0.0314                -0.0158
# 2018-11                -0.0068     -0.0053                -0.0193
#
#          Emerging Markets  Equity Market Neutral  Event Driven  \
# date
# 1997-01            0.0791                 0.0189        0.0213
# ...

# %%
# Q1:
gaussian_var = erk.var_gaussian(hfi["2000":]["Distressed Securities"],level=1,modified=False)
gaussian_var
# Out:
# 0.03143017693928047

# %%
# Q2
mod_gaussian_var = erk.var_gaussian(hfi["2000":]["Distressed Securities"],level=1,modified=True)
mod_gaussian_var
# Out:
# 0.04966909110627918

# %%
# Q3
hist_var = erk.var_historic(hfi["2000":]["Distressed Securities"],level=1)
hist_var
# Out:
# 0.042642

# %%
ind = erk.get_ind_returns()
l = ['Books', 'Steel', 'Oil', 'Mines']
ind = ind["2013":"2017"][l]
ind
# Out:
#           Books   Steel     Oil   Mines
# 2013-01  0.0513  0.0428  0.0788  0.0059
# 2013-02 -0.0654 -0.0268  0.0052 -0.0756
# 2013-03  0.0778  0.0210  0.0209  0.0091
# 2013-04 -0.0029 -0.0441 -0.0129 -0.1057
# 2013-05  0.0479  0.0384  0.0307  0.0022
# 2013-06  0.0246 -0.0472 -0.0211 -0.0959
# 2013-07  0.1207  0.0697  0.0496  0.0002
# 2013-08 -0.0488 -0.0275 -0.0193  0.0459
# 2013-09  0.0626  0.0835  0.0189  0.0116
# 2013-10  0.0718  0.0838  0.0472  0.0534
# 2013-11  0.0021  0.0172  0.0098 -0.0558
# 2013-12  0.0775  0.0652  0.0290  0.0684
# 2014-01 -0.0712 -0.0547 -0.0703 -0.0643
# 2014-02  0.0673  0.0255  0.0571  0.0656
# 2014-03 -0.0075  0.0367  0.0251 -0.0064
# 2014-04 -0.0209  0.0065  0.0564  0.0294
# 2014-05 -0.0153 -0.0162  0.0096 -0.0217
# 2014-06  0.0880  0.0489  0.0416  0.0629
# 2014-07 -0.0160  0.0220 -0.0349  0.0193
# 2014-08  0.0264  0.0621  0.0225  0.0134
# 2014-09 -0.0729 -0.0479 -0.0798 -0.1077
# 2014-10  0.0328  0.0217 -0.0447 -0.0928
# ...

# %%
er = erk.annualize_rets(ind, 12)
cov = ind.cov()
cov
# Out:
#           Books     Steel       Oil     Mines
# Books  0.002720  0.001940  0.001637  0.001539
# Steel  0.001940  0.004391  0.002122  0.003391
# Oil    0.001637  0.002122  0.002697  0.002179
# Mines  0.001539  0.003391  0.002179  0.005232

# %%
# Q4
EW_steel = 1/ind[l].shape[1]
EW_steel
# Out:
# 0.25

# %%
# Q5 , Q6
msr_weights = erk.msr(0.1, er, cov)
(msr_weights.max(),l[msr_weights.argmax()])
# Out:
# (1.0, 'Steel')

# %%
# Q7
msr_weights
# Out:
# array([0.00000000e+00, 1.00000000e+00, 2.08166817e-17, 6.01949046e-16])

# %%
# Q8 , Q9
weight_gmv = erk.gmv(cov)
(weight_gmv.max(), l[weight_gmv.argmax()])
# Out:
# (0.47702487014389955, 'Books')

# %%
# Q10
weight_gmv
# Out:
# array([0.47702487, 0.        , 0.43411203, 0.0888631 ])

# %%
# Q11
ind = erk.get_ind_returns()
ind = ind["2018"][l]
vol_msr = erk.portfolio_vol(msr_weights,ind.cov())*(12**0.5)
vol_msr
# Out:
# 0.21983988181484188

# %%
# Q12
vol_gmv = erk.portfolio_vol(weight_gmv,ind.cov())*(12**0.5)
vol_gmv
# Out:
# 0.18973734520184568
